# %%
import nltk
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
from nltk.corpus import brown
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

nltk.download('punkt')
nltk.download('brown')

# %%
sentences = brown.sents()
model = Word2Vec(sentences=sentences, vector_size=100, window=5, min_count=5, sg=1, workers=4)
print("\nMost similar words to 'money':")
print(model.wv.most_similar('science'))
# Out:
# Most similar words to 'money':
# [('religion', 0.9072743654251099), ('philosophy', 0.9021623730659485), ('fundamental', 0.8842729926109314), ('scientific', 0.88246750831604), ('politics', 0.8806292414665222), ('historical', 0.8799067139625549), ('fiction', 0.8697726130485535), ('sciences', 0.869384229183197), ('imagination', 0.8688012361526489), ('widespread', 0.8664730191230774)]

# %%
words = ['king', 'queen', 'man', 'woman', 'money', 'bank', 'school', 'teacher', 'student', 'war']
word_vecs = [model.wv[word] for word in words]
pca=PCA(n_components=2)
result=pca.fit_transform(word_vecs)

# %%
plt.figure(figsize=(8, 6))
for i, word in enumerate(words):
    plt.scatter(result[i, 0], result[i, 1])
    plt.text(result[i, 0] + 0.01, result[i, 1] + 0.01, word)
plt.title("Word2Vec Word Embeddings (PCA Projection)")
plt.grid(True)
plt.tight_layout()
plt.show()
